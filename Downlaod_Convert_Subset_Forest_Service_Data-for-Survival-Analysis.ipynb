# %% [markdown]
# # Downloading, converting, and subsetting Forest Service data
# * Author: Katie Murenbeeld
# * Date: 19 Nov 2019
# * Updated: 09 Dec 2019
# * Updated: 23 May 2020, for use in a survival analysis
# * Updated: 24 June 2020, needed to fix the fillna for incomplete activities and projects
#
# ## Introduction:
# Within this notebook I will show you:
# 1. Where to retrieve and download Forest Service activity data
# 2. How to convert the data to a .csv file
# 3. How to "subset" the data for the desired state and information
# 4. How to convert the planned and completed dates to serial dates
# 5. How to reclassify the treatment activities.
# 6. How to calculate Time Lag (the difference between completed and planned date) and the difference in planned and completed area treated and store in a new column
# 7. How to create a new column "Completed" and fill with binary data, where 0 = FALSE (i.e. not completed) and 1 = TRUE (i.e. completed).
# 7. Write out a .csv file with the modified dataset

# %% [markdown]
# ### 1. Retrieve and download Forest Service activity data
# Forest Service activity data can be found at here: https://data.fs.usda.gov/geodata/edw/datasets.php
#
# Please chose the dataset you would like to work with (in this notebook I will be using the Timber Harvest data) by clicking on the shapefile link for the desired dataset (insert screen shot here). Clicking on the link will automatically start the download. Once download is complete, move the dataset to your desired location.
#
# * Note: The metadata for the file is also useful and will define the different code names and numbers.
#
# After you move the downloaded data, set the directories for your raw data and for the resulting .csv files.

# %%
# Set directories

raw_data_dir = '/Users/kathrynmurenbeeld/CODING/FOREST-TREATMENTS/DATA/FOREST-TREATMENTS/RAW/'
mod_data_dir = '/Users/kathrynmurenbeeld/CODING/FOREST-TREATMENTS/DATA/FOREST-TREATMENTS/MOD/'

# %% [markdown]
# ### 2. Convert the data to a .csv file
# Remember, the file you downloaded is a shape file. There are several files that comprise a GIS/ESRI shapefile. One of these is a .dbf. The .dbf is the file that will be converted to a .csv file. The conversion will produce a rather large .csv that should be stored in your modified data directory (mod_data_dir). To convert the data you will need a specific library called _simpledbf_ and the tool _Dbf5_ from _simpledbf_.
#
# Before starting, I recommend that you rename the .dbf to reflect when you downloaded the raw data.

# %%
# Download the relevant libraries
import simpledbf 
from simpledbf import Dbf5 

# Other important libraries
import pandas as pd #For working with dataframes
import numpy as np #For working with arrays
import datetime as dt #For converting dates to serial datetimes

# %%
# Convert the most up to date timber harvest data from dbf to csv
# It is useful to use a name that reflects the general time that you
# downloaded the data.

#dbf = Dbf5(raw_data_dir + 'S_USA_Activity_TimberHarvest_july2019.dbf', codec='utf-8') # Import the dbf and assign the code 

#dbf.to_csv(mod_data_dir + 'USA_TH_JULY2019.csv') # Covert to csv

# %%
# Use pandas to create dataframe from new csv
df = pd.read_csv(mod_data_dir + 'USA_TH_JULY2019.csv').reset_index()
df.head(1) # Show the first row of the dataframe as a check.
# Out:
#    index  ADMIN_FORE  ADMIN_REGI              ADMIN_FO_1  PROCLAIMED  \
# 0      0           6           5  Lassen National Forest         506
#
#                 ADMIN_DIST  ADMIN_DI_1  HOME_ORG  ACTIVITY_U  \
# 0  Almanor Ranger District          51     50651       50651
#
#                   SUID  ... DATA_SOU_1 ACCURACY  CRC_VALUE  UK  EDW_INSERT  \
# 0  050651T376000076000  ...        NaN      0.0        NaN NaN  2019-07-01
#
#    ETL_MODIFI    REV_DATE GIS_ACRES SHAPE_AREA  SHAPE_LEN
# 0  2019-07-01  2018-01-09    25.759   0.000011   0.026648
#
# [1 rows x 69 columns]

# %% [markdown]
# ### 3. Subset the data for the desired area (state, region, or forest) of interest.
# As you can see, there are many columns with this data. Review the metadata to decide which columns will be most useful. In this case, I only want to look at columns:
# 1. STATE_ABBR, the state
# 2. ADMIN_FORE, the number for associated with a National Forest (sometimes the name is missing from the dataset)
# 3. ADMIN_FO_1, the name of the National Forest
# 4. NEPA_DOC_N, the name of a Forest Service project, which are comprised of different activities.
# 5. ACTIVITY_N, the name of the activity
# 6. ACTIVITY_2, may be ACTIVITY_C in other datasets, the numerical activity code
# 7. NBR_UNITS_, the number of acres planned to be treated by an activity
# 8. NBR_UNITS1, the number of acres actually treated by an activity
# 9. DATE_PLANN, the date an activity was planned to be completed
# 10. DATE_COMPL, the date an activity was actually completed
#
# One could also include ADMIN_REGI to look at Forest Service administrative regions.
#
# For this example, I will then subset the reduced dataframe by state (i.e. Idaho).

# %%
# Create a new dataframe the columns from the dataframe
df2 = df[['STATE_ABBR','ADMIN_FORE','ADMIN_FO_1','NEPA_DOC_N','ACTIVITY_N',
         'ACTIVITY_2','NBR_UNITS_','NBR_UNITS1','DATE_PLANN','DATE_COMPL']].copy()

# .copy() is important...

df2.head(1) # Check that the correct columns are in the new dataframe
# Out:
#   STATE_ABBR  ADMIN_FORE              ADMIN_FO_1  \
# 0         CA           6  Lassen National Forest
#
#                                           NEPA_DOC_N       ACTIVITY_N  \
# 0  (PALS)CREEKS II FOREST RESTORATION PROJECT FEI...  Commercial Thin
#
#    ACTIVITY_2  NBR_UNITS_  NBR_UNITS1  DATE_PLANN DATE_COMPL
# 0        4220        26.0        26.0  2018-03-01        NaN

# %% [markdown]
# Finally, create a new data frame with only the data for Idaho. Use the .loc function in pandas to essentially slice the data by state.

# %%
# Use .loc and slice where column STATE_ABBR is equal to ID.
df_id = df2.loc[df2['STATE_ABBR']=='ID'].copy()
df_id.head(5) # Check the new dataframe
# Out:
#    STATE_ABBR  ADMIN_FORE                              ADMIN_FO_1  \
# 4          ID          17  Nez Perce - Clearwater National Forest
# 14         ID           4        Idaho Panhandle National Forests
# 36         ID           4        Idaho Panhandle National Forests
# 49         ID           4        Idaho Panhandle National Forests
# 50         ID           4        Idaho Panhandle National Forests
#
#                   NEPA_DOC_N  \
# 4   DEFAULT FOR NOT REQUIRED
# 14  DEFAULT FOR NOT REQUIRED
# 36  DEFAULT FOR NOT REQUIRED
# 49  DEFAULT FOR NOT REQUIRED
# 50  DEFAULT FOR NOT REQUIRED
#
#                                            ACTIVITY_N  ACTIVITY_2  NBR_UNITS_  \
# 4   Shelterwood Establishment Cut (with or without...        4131         6.0
# 14  Salvage Cut (intermediate treatment, not regen...        4231        32.0
# 36                          Stand Clearcut (EA/RH/FH)        4113         6.0
# 49                          Stand Clearcut (EA/RH/FH)        4113        18.0
# 50  Salvage Cut (intermediate treatment, not regen...        4231        29.0
#
#     NBR_UNITS1  DATE_PLANN  DATE_COMPL
# 4          6.0  1987-07-01  1987-07-01
# 14        32.0  1968-06-01  1968-06-01
# 36         6.0  1985-07-01  1985-07-01
# 49        18.0  1969-06-01  1969-06-01
# 50        29.0  1953-08-01  1953-08-01

# %% [markdown]
# ### 4. Convert the planned and completed dates to serial dates.
# In order to analyze this data through time, the current date data must be converted into serial dates using the datetime library. A new column will be added to the data frame for the new serial dates.

# %%
# Convert DATE_* columns to datetime. Add a new column for the serial dates

# Create a numpy array of all the Date Planned values
id_datearrP = df_id['DATE_PLANN'].values 
# Convert the values in that array to a serial datetime and name as a new variable
id_datearr_dtP = pd.to_datetime(id_datearrP) 
# Add a new column to the dataframe of the converted datetime
df_id['SerDatesPlan'] = id_datearr_dtP 

# Repeat for the Date Completed

# Create a numpy array of all the Date Completed values
id_datearrC = df_id['DATE_COMPL'].values
id_datearr_dtC = pd.to_datetime(id_datearrC)
df_id['SerDatesComp'] = id_datearr_dtC

df_id.head(1) # Check to make sure the new columns show up
# Out:
#   STATE_ABBR  ADMIN_FORE                              ADMIN_FO_1  \
# 4         ID          17  Nez Perce - Clearwater National Forest
#
#                  NEPA_DOC_N  \
# 4  DEFAULT FOR NOT REQUIRED
#
#                                           ACTIVITY_N  ACTIVITY_2  NBR_UNITS_  \
# 4  Shelterwood Establishment Cut (with or without...        4131         6.0
#
#    NBR_UNITS1  DATE_PLANN  DATE_COMPL SerDatesPlan SerDatesComp
# 4         6.0  1987-07-01  1987-07-01   1987-07-01   1987-07-01

# %% [markdown]
# Other useful columns to add include:
# 1. A column for year planned ('YP')
# 2. A column for year completed ('YC')
#
# This will be useful for looking at the total number of times a treatment occurred through time and the total area completed through time. By looking at yearly totals, the resulting figures will look better.

# %%
# Use datetime to retrieve the year values.

df_id['YP'] = df_id['SerDatesPlan'].dt.year
df_id['YC'] = df_id['SerDatesComp'].dt.year

# Check that the two new columns showed up and are correct.
df_id.head(1)

# Note, the results may need to be an integer not a float and vice versa. 
# Some activities have not been completed, so YC will have some Nan values
# which makes the entire YC column data floats. Due to the Nans you may recieve an error
# in which case Nans may need to go to 0 and then be converted to float or integer.

# If need be, convert floats to integers.
# Check the data type using pandas .dtype
df_id['YC'].dtype
# Out:
# dtype('float64')

# %%
# Replace Nan with 0 if desired.


# Convert float to integer
#df_id.astype({'YC': 'int64'}).dtypes 

# Check data type again
#df_id['YC'].dtype

# %% [markdown]
# ### 5. Reclassify the treatment activities.
#
# Reclassify the treatment activites as you see fit using the metadat from the Forest Service data website to inform you (https://data.fs.usda.gov/geodata/edw/datasets.php). In this case the activities were reclassified into 14 groups based on the objective of the activity and the fraction of trees that are retained.

# %%
# Group some of the activities together for later use. Use np.select(conditions, choices, default=). 
# Set your conditions to the ACTIVITY_2 codes, use isin() for when multiple codes will be grouped.

conditions = [
    (df_id['ACTIVITY_2']==4113), 
    (df_id['ACTIVITY_2']==4177),
    (df_id['ACTIVITY_2']==4111),
    (df_id['ACTIVITY_2']==4175),
    (df_id['ACTIVITY_2']==4152),
    (df_id['ACTIVITY_2']==4151),
    (df_id['ACTIVITY_2']==4220),
    (df_id['ACTIVITY_2'].isin([4231,4232,4210,4211])),
    (df_id['ACTIVITY_2'].isin([4102,4121,4131,4132])),
    (df_id['ACTIVITY_2'].isin([4192,4194,4162])),
    (df_id['ACTIVITY_2'].isin([4141,4142,4145,4146])),
    (df_id['ACTIVITY_2'].isin([4148,4196,4183,4193])),
    (df_id['ACTIVITY_2']==4143),
    (df_id['ACTIVITY_2']==4242)
]
choices = ['SCC','A2_SCC','PCC','A2_PCC','GT_CUT','ST_CUT','COMM_THIN','INT_CUT','REGEN_PREP','REGEN_PREP10','REGEN_REMOVE','REGEN_REMOVE10','OVERSTORE_CUT','HARV_NOSTOCK']

# %%
# Use np.select() to create a new column with the coded/grouped activities.

df_id['NEW_CODE'] = np.select(conditions, choices, default='none')
df_id.head(2) # check the data
# Out:
#    STATE_ABBR  ADMIN_FORE                              ADMIN_FO_1  \
# 4          ID          17  Nez Perce - Clearwater National Forest
# 14         ID           4        Idaho Panhandle National Forests
#
#                   NEPA_DOC_N  \
# 4   DEFAULT FOR NOT REQUIRED
# 14  DEFAULT FOR NOT REQUIRED
#
#                                            ACTIVITY_N  ACTIVITY_2  NBR_UNITS_  \
# 4   Shelterwood Establishment Cut (with or without...        4131         6.0
# 14  Salvage Cut (intermediate treatment, not regen...        4231        32.0
#
#     NBR_UNITS1  DATE_PLANN  DATE_COMPL SerDatesPlan SerDatesComp    YP  \
# 4          6.0  1987-07-01  1987-07-01   1987-07-01   1987-07-01  1987
# 14        32.0  1968-06-01  1968-06-01   1968-06-01   1968-06-01  1968
#
#         YC    NEW_CODE
# 4   1987.0  REGEN_PREP
# 14  1968.0     INT_CUT

# %% [markdown]
# ### 6. Calculate the _time lag_ from planned to completed and the difference in area treated from planned to completed.
# Use simple subtraction to calculated _time lag_ and the difference in area. Add these new values as new columns to the dataframe.

# %%
df_id['TIME_LAG'] = (df_id['SerDatesComp'] - df_id['SerDatesPlan']).dt.days
df_id.head(1) # check the new column
# Out:
#   STATE_ABBR  ADMIN_FORE                              ADMIN_FO_1  \
# 4         ID          17  Nez Perce - Clearwater National Forest
#
#                  NEPA_DOC_N  \
# 4  DEFAULT FOR NOT REQUIRED
#
#                                           ACTIVITY_N  ACTIVITY_2  NBR_UNITS_  \
# 4  Shelterwood Establishment Cut (with or without...        4131         6.0
#
#    NBR_UNITS1  DATE_PLANN  DATE_COMPL SerDatesPlan SerDatesComp    YP      YC  \
# 4         6.0  1987-07-01  1987-07-01   1987-07-01   1987-07-01  1987  1987.0
#
#      NEW_CODE  TIME_LAG
# 4  REGEN_PREP       0.0

# %%
df_id['AREA_DIFF'] = (df_id['NBR_UNITS1'] - df_id['NBR_UNITS_'])
df_id.head(2) # check the new column
# Out:
#    STATE_ABBR  ADMIN_FORE                              ADMIN_FO_1  \
# 4          ID          17  Nez Perce - Clearwater National Forest
# 14         ID           4        Idaho Panhandle National Forests
#
#                   NEPA_DOC_N  \
# 4   DEFAULT FOR NOT REQUIRED
# 14  DEFAULT FOR NOT REQUIRED
#
#                                            ACTIVITY_N  ACTIVITY_2  NBR_UNITS_  \
# 4   Shelterwood Establishment Cut (with or without...        4131         6.0
# 14  Salvage Cut (intermediate treatment, not regen...        4231        32.0
#
#     NBR_UNITS1  DATE_PLANN  DATE_COMPL SerDatesPlan SerDatesComp    YP  \
# 4          6.0  1987-07-01  1987-07-01   1987-07-01   1987-07-01  1987
# 14        32.0  1968-06-01  1968-06-01   1968-06-01   1968-06-01  1968
#
#         YC    NEW_CODE  TIME_LAG  AREA_DIFF
# 4   1987.0  REGEN_PREP       0.0        0.0
# 14  1968.0     INT_CUT       0.0        0.0

# %% [markdown]
# ### 7. Create a column named Completed and fill with 0 if activity has not been completed or 1 if the activity has been completed. Create a column named NEPA and fill with 0 if activity did not require NEPA or 1 if the activity did require NEPA.

# %%
df_id['DATE_COMPL'].fillna("IC", inplace = True)
df_id['TIME_LAG'].fillna("IC", inplace = True)
#data["Gender"].fillna("No Gender", inplace = True)

df_id.head(23)
# Out:
#     STATE_ABBR  ADMIN_FORE                              ADMIN_FO_1  \
# 4           ID          17  Nez Perce - Clearwater National Forest
# 14          ID           4        Idaho Panhandle National Forests
# 36          ID           4        Idaho Panhandle National Forests
# 49          ID           4        Idaho Panhandle National Forests
# 50          ID           4        Idaho Panhandle National Forests
# 51          ID          13          Salmon-Challis National Forest
# 67          ID           4        Idaho Panhandle National Forests
# 70          ID           4        Idaho Panhandle National Forests
# 82          ID          17  Nez Perce - Clearwater National Forest
# 96          ID           4        Idaho Panhandle National Forests
# 102         ID          12                 Payette National Forest
# 107         ID           5                                     NaN
# 116         ID          17  Nez Perce - Clearwater National Forest
# 129         ID           5                                     NaN
# 161         ID           4        Idaho Panhandle National Forests
# 177         ID          17  Nez Perce - Clearwater National Forest
# 193         ID           5                                     NaN
# 195         ID           4        Idaho Panhandle National Forests
# 203         ID           5                                     NaN
# 221         ID          15         Caribou-Targhee National Forest
# 224         ID          17  Nez Perce - Clearwater National Forest
# 239         ID           5                                     NaN
# 242         ID          12                 Payette National Forest
#
#                                             NEPA_DOC_N  \
# 4                             DEFAULT FOR NOT REQUIRED
# 14                            DEFAULT FOR NOT REQUIRED
# 36                            DEFAULT FOR NOT REQUIRED
# 49                            DEFAULT FOR NOT REQUIRED
# 50                            DEFAULT FOR NOT REQUIRED
# 51   (PALS)DECISION MEMO FOR DEEP CREEK RIDGE SALVA...
# 67                            DEFAULT FOR NOT REQUIRED
# 70                            DEFAULT FOR NOT REQUIRED
# 82                            DEFAULT FOR NOT REQUIRED
# 96                            DEFAULT FOR NOT REQUIRED
# 102                           DEFAULT FOR NOT REQUIRED
# 107                           DEFAULT FOR NOT REQUIRED
# 116                           DEFAULT FOR NOT REQUIRED
# 129                           DEFAULT FOR NOT REQUIRED
# 161                           DEFAULT FOR NOT REQUIRED
# 177                           DEFAULT FOR NOT REQUIRED
# 193                           DEFAULT FOR NOT REQUIRED
# 195                           DEFAULT FOR NOT REQUIRED
# 203                           DEFAULT FOR NOT REQUIRED
# 221                           DEFAULT FOR NOT REQUIRED
# 224                 AMERICAN AND CROOKED RIVER PROJECT
# 239                           DEFAULT FOR NOT REQUIRED
# 242                           DEFAULT FOR NOT REQUIRED
#
#                                             ACTIVITY_N  ACTIVITY_2  \
# 4    Shelterwood Establishment Cut (with or without...        4131
# 14   Salvage Cut (intermediate treatment, not regen...        4231
# 36                           Stand Clearcut (EA/RH/FH)        4113
# 49                           Stand Clearcut (EA/RH/FH)        4113
# 50   Salvage Cut (intermediate treatment, not regen...        4231
# 51                                     Commercial Thin        4220
# 67                           Stand Clearcut (EA/RH/FH)        4113
# 70   Shelterwood Establishment Cut (with or without...        4131
# 82   Shelterwood Establishment Cut (with or without...        4131
# 96                           Stand Clearcut (EA/RH/FH)        4113
# 102                                    Commercial Thin        4220
# 107  Salvage Cut (intermediate treatment, not regen...        4231
# 116                          Patch Clearcut (EA/RH/FH)        4111
# 129  Seed-tree Seed Cut (with and without leave tre...        4132
# 161                          Stand Clearcut (EA/RH/FH)        4113
# 177  Shelterwood Establishment Cut (with or without...        4131
# 193                          Patch Clearcut (EA/RH/FH)        4111
# 195               Single-tree Selection Cut (UA/RH/FH)        4151
# 203  Salvage Cut (intermediate treatment, not regen...        4231
# 221                          Stand Clearcut (EA/RH/FH)        4113
# 224  Salvage Cut (intermediate treatment, not regen...        4231
# 239                                    Commercial Thin        4220
# 242               Single-tree Selection Cut (UA/RH/FH)        4151
#
#      NBR_UNITS_  NBR_UNITS1  DATE_PLANN  DATE_COMPL SerDatesPlan SerDatesComp  \
# 4           6.0         6.0  1987-07-01  1987-07-01   1987-07-01   1987-07-01
# 14         32.0        32.0  1968-06-01  1968-06-01   1968-06-01   1968-06-01
# 36          6.0         6.0  1985-07-01  1985-07-01   1985-07-01   1985-07-01
# 49         18.0        18.0  1969-06-01  1969-06-01   1969-06-01   1969-06-01
# 50         29.0        29.0  1953-08-01  1953-08-01   1953-08-01   1953-08-01
# 51          8.0         8.0  2013-06-05  2018-09-13   2013-06-05   2018-09-13
# 67         16.0        16.0  1988-04-28  1991-09-01   1988-04-28   1991-09-01
# 70        250.0       250.0  1960-11-04  1962-10-01   1960-11-04   1962-10-01
# 82         22.0        22.0  1981-06-01  1981-06-01   1981-06-01   1981-06-01
# 96         22.0        22.0  1950-08-01  1950-08-01   1950-08-01   1950-08-01
# 102        34.0        34.0  1973-09-30  1973-09-30   1973-09-30   1973-09-30
# 107        12.0        12.0  1961-10-01  1961-10-01   1961-10-01   1961-10-01
# 116        82.0        82.0  1972-10-01  1972-10-01   1972-10-01   1972-10-01
# 129        10.0        10.0  1983-10-01  1983-10-01   1983-10-01   1983-10-01
# 161        23.0        23.0  1991-10-01  1991-10-01   1991-10-01   1991-10-01
# 177        17.0        17.0  1994-05-01  1994-05-01   1994-05-01   1994-05-01
# 193         1.0         1.0  1983-09-01  1983-09-01   1983-09-01   1983-09-01
# 195         7.0         7.0  1922-10-01  1923-10-01   1922-10-01   1923-10-01
# 203        29.0        29.0  1976-06-01  1976-06-01   1976-06-01   1976-06-01
# 221        16.0        16.0  1986-09-30  1986-09-30   1986-09-30   1986-09-30
# 224        25.0        25.0  2006-07-01  2006-11-01   2006-07-01   2006-11-01
# 239        12.0        12.0  2013-09-29          IC   2013-09-29          NaT
# 242        11.0        11.0  1976-09-01  1976-09-01   1976-09-01   1976-09-01
#
#        YP      YC    NEW_CODE TIME_LAG  AREA_DIFF Completed NEPA
# 4    1987  1987.0  REGEN_PREP        0        0.0         1    0
# 14   1968  1968.0     INT_CUT        0        0.0         1    0
# 36   1985  1985.0         SCC        0        0.0         1    0
# 49   1969  1969.0         SCC        0        0.0         1    0
# 50   1953  1953.0     INT_CUT        0        0.0         1    0
# 51   2013  2018.0   COMM_THIN     1926        0.0         1    1
# 67   1988  1991.0         SCC     1221        0.0         1    0
# 70   1960  1962.0  REGEN_PREP      696        0.0         1    0
# 82   1981  1981.0  REGEN_PREP        0        0.0         1    0
# 96   1950  1950.0         SCC        0        0.0         1    0
# 102  1973  1973.0   COMM_THIN        0        0.0         1    0
# 107  1961  1961.0     INT_CUT        0        0.0         1    0
# 116  1972  1972.0         PCC        0        0.0         1    0
# 129  1983  1983.0  REGEN_PREP        0        0.0         1    0
# 161  1991  1991.0         SCC        0        0.0         1    0
# 177  1994  1994.0  REGEN_PREP        0        0.0         1    0
# 193  1983  1983.0         PCC        0        0.0         1    0
# 195  1922  1923.0      ST_CUT      365        0.0         1    0
# 203  1976  1976.0     INT_CUT        0        0.0         1    0
# 221  1986  1986.0         SCC        0        0.0         1    0
# 224  2006  2006.0     INT_CUT      123        0.0         1    1
# 239  2013     NaN   COMM_THIN       IC        0.0         1    0
# 242  1976  1976.0      ST_CUT        0        0.0         1    0

# %%
conditions2 = [ (df_id['TIME_LAG'] == "IC"), (df_id['TIME_LAG'] != "IC")]

choices2 = [0, 1]

conditions3 = [ (df_id['NEPA_DOC_N'] == "DEFAULT FOR NOT REQUIRED"), (df_id['NEPA_DOC_N'] != "DEFAULT FOR NOT REQUIRED")]

choices3 = [0, 1]

df_id['Completed'] = np.select(conditions2, choices2, default='none')

df_id['NEPA'] = np.select(conditions3, choices3, default='none')

# %%
# Optional: drop the DATE_PLANN and DATE_COMPL columns to clean table up more.
#df_id = df_id.drop(['DATE_PLANN', 'DATE_COMP', 'YP', 'YC'], axis=1)
df_id.head(23) # Check that the columns were dropped
# Out:
#     STATE_ABBR  ADMIN_FORE                              ADMIN_FO_1  \
# 4           ID          17  Nez Perce - Clearwater National Forest
# 14          ID           4        Idaho Panhandle National Forests
# 36          ID           4        Idaho Panhandle National Forests
# 49          ID           4        Idaho Panhandle National Forests
# 50          ID           4        Idaho Panhandle National Forests
# 51          ID          13          Salmon-Challis National Forest
# 67          ID           4        Idaho Panhandle National Forests
# 70          ID           4        Idaho Panhandle National Forests
# 82          ID          17  Nez Perce - Clearwater National Forest
# 96          ID           4        Idaho Panhandle National Forests
# 102         ID          12                 Payette National Forest
# 107         ID           5                                     NaN
# 116         ID          17  Nez Perce - Clearwater National Forest
# 129         ID           5                                     NaN
# 161         ID           4        Idaho Panhandle National Forests
# 177         ID          17  Nez Perce - Clearwater National Forest
# 193         ID           5                                     NaN
# 195         ID           4        Idaho Panhandle National Forests
# 203         ID           5                                     NaN
# 221         ID          15         Caribou-Targhee National Forest
# 224         ID          17  Nez Perce - Clearwater National Forest
# 239         ID           5                                     NaN
# 242         ID          12                 Payette National Forest
#
#                                             NEPA_DOC_N  \
# 4                             DEFAULT FOR NOT REQUIRED
# 14                            DEFAULT FOR NOT REQUIRED
# 36                            DEFAULT FOR NOT REQUIRED
# 49                            DEFAULT FOR NOT REQUIRED
# 50                            DEFAULT FOR NOT REQUIRED
# 51   (PALS)DECISION MEMO FOR DEEP CREEK RIDGE SALVA...
# 67                            DEFAULT FOR NOT REQUIRED
# 70                            DEFAULT FOR NOT REQUIRED
# 82                            DEFAULT FOR NOT REQUIRED
# 96                            DEFAULT FOR NOT REQUIRED
# 102                           DEFAULT FOR NOT REQUIRED
# 107                           DEFAULT FOR NOT REQUIRED
# 116                           DEFAULT FOR NOT REQUIRED
# 129                           DEFAULT FOR NOT REQUIRED
# 161                           DEFAULT FOR NOT REQUIRED
# 177                           DEFAULT FOR NOT REQUIRED
# 193                           DEFAULT FOR NOT REQUIRED
# 195                           DEFAULT FOR NOT REQUIRED
# 203                           DEFAULT FOR NOT REQUIRED
# 221                           DEFAULT FOR NOT REQUIRED
# 224                 AMERICAN AND CROOKED RIVER PROJECT
# 239                           DEFAULT FOR NOT REQUIRED
# 242                           DEFAULT FOR NOT REQUIRED
#
#                                             ACTIVITY_N  ACTIVITY_2  \
# 4    Shelterwood Establishment Cut (with or without...        4131
# 14   Salvage Cut (intermediate treatment, not regen...        4231
# 36                           Stand Clearcut (EA/RH/FH)        4113
# 49                           Stand Clearcut (EA/RH/FH)        4113
# 50   Salvage Cut (intermediate treatment, not regen...        4231
# 51                                     Commercial Thin        4220
# 67                           Stand Clearcut (EA/RH/FH)        4113
# 70   Shelterwood Establishment Cut (with or without...        4131
# 82   Shelterwood Establishment Cut (with or without...        4131
# 96                           Stand Clearcut (EA/RH/FH)        4113
# 102                                    Commercial Thin        4220
# 107  Salvage Cut (intermediate treatment, not regen...        4231
# 116                          Patch Clearcut (EA/RH/FH)        4111
# 129  Seed-tree Seed Cut (with and without leave tre...        4132
# 161                          Stand Clearcut (EA/RH/FH)        4113
# 177  Shelterwood Establishment Cut (with or without...        4131
# 193                          Patch Clearcut (EA/RH/FH)        4111
# 195               Single-tree Selection Cut (UA/RH/FH)        4151
# 203  Salvage Cut (intermediate treatment, not regen...        4231
# 221                          Stand Clearcut (EA/RH/FH)        4113
# 224  Salvage Cut (intermediate treatment, not regen...        4231
# 239                                    Commercial Thin        4220
# 242               Single-tree Selection Cut (UA/RH/FH)        4151
#
#      NBR_UNITS_  NBR_UNITS1  DATE_PLANN  DATE_COMPL SerDatesPlan SerDatesComp  \
# 4           6.0         6.0  1987-07-01  1987-07-01   1987-07-01   1987-07-01
# 14         32.0        32.0  1968-06-01  1968-06-01   1968-06-01   1968-06-01
# 36          6.0         6.0  1985-07-01  1985-07-01   1985-07-01   1985-07-01
# 49         18.0        18.0  1969-06-01  1969-06-01   1969-06-01   1969-06-01
# 50         29.0        29.0  1953-08-01  1953-08-01   1953-08-01   1953-08-01
# 51          8.0         8.0  2013-06-05  2018-09-13   2013-06-05   2018-09-13
# 67         16.0        16.0  1988-04-28  1991-09-01   1988-04-28   1991-09-01
# 70        250.0       250.0  1960-11-04  1962-10-01   1960-11-04   1962-10-01
# 82         22.0        22.0  1981-06-01  1981-06-01   1981-06-01   1981-06-01
# 96         22.0        22.0  1950-08-01  1950-08-01   1950-08-01   1950-08-01
# 102        34.0        34.0  1973-09-30  1973-09-30   1973-09-30   1973-09-30
# 107        12.0        12.0  1961-10-01  1961-10-01   1961-10-01   1961-10-01
# 116        82.0        82.0  1972-10-01  1972-10-01   1972-10-01   1972-10-01
# 129        10.0        10.0  1983-10-01  1983-10-01   1983-10-01   1983-10-01
# 161        23.0        23.0  1991-10-01  1991-10-01   1991-10-01   1991-10-01
# 177        17.0        17.0  1994-05-01  1994-05-01   1994-05-01   1994-05-01
# 193         1.0         1.0  1983-09-01  1983-09-01   1983-09-01   1983-09-01
# 195         7.0         7.0  1922-10-01  1923-10-01   1922-10-01   1923-10-01
# 203        29.0        29.0  1976-06-01  1976-06-01   1976-06-01   1976-06-01
# 221        16.0        16.0  1986-09-30  1986-09-30   1986-09-30   1986-09-30
# 224        25.0        25.0  2006-07-01  2006-11-01   2006-07-01   2006-11-01
# 239        12.0        12.0  2013-09-29          IC   2013-09-29          NaT
# 242        11.0        11.0  1976-09-01  1976-09-01   1976-09-01   1976-09-01
#
#        YP      YC    NEW_CODE TIME_LAG  AREA_DIFF Completed NEPA
# 4    1987  1987.0  REGEN_PREP        0        0.0         1    0
# 14   1968  1968.0     INT_CUT        0        0.0         1    0
# 36   1985  1985.0         SCC        0        0.0         1    0
# 49   1969  1969.0         SCC        0        0.0         1    0
# 50   1953  1953.0     INT_CUT        0        0.0         1    0
# 51   2013  2018.0   COMM_THIN     1926        0.0         1    1
# 67   1988  1991.0         SCC     1221        0.0         1    0
# 70   1960  1962.0  REGEN_PREP      696        0.0         1    0
# 82   1981  1981.0  REGEN_PREP        0        0.0         1    0
# 96   1950  1950.0         SCC        0        0.0         1    0
# 102  1973  1973.0   COMM_THIN        0        0.0         1    0
# 107  1961  1961.0     INT_CUT        0        0.0         1    0
# 116  1972  1972.0         PCC        0        0.0         1    0
# 129  1983  1983.0  REGEN_PREP        0        0.0         1    0
# 161  1991  1991.0         SCC        0        0.0         1    0
# 177  1994  1994.0  REGEN_PREP        0        0.0         1    0
# 193  1983  1983.0         PCC        0        0.0         1    0
# 195  1922  1923.0      ST_CUT      365        0.0         1    0
# 203  1976  1976.0     INT_CUT        0        0.0         1    0
# 221  1986  1986.0         SCC        0        0.0         1    0
# 224  2006  2006.0     INT_CUT      123        0.0         1    1
# 239  2013     NaN   COMM_THIN       IC        0.0         0    0
# 242  1976  1976.0      ST_CUT        0        0.0         1    0

# %% [markdown]
# ### 7. Write to .csv file
# Write the final version of the data frame to a .csv file and store in the mod_data_dir. Name in such a way that you will know this is for timber harvests in Idaho.

# %%
# Use pandas .to_csv to convert a dataframe to a .csv file. 
# The default encoding is utf-8, but this can be adjusted if desired.

df_id.to_csv(mod_data_dir + 'ID_TH_20200624_survana_v03.csv')
