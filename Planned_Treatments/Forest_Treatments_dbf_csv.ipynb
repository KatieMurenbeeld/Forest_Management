# %% [markdown]
# ## Code for Importing and Converting Forest Treatment Data from dbf to csv
# ### By: Katie Murenbeeld
# ### Date: 25 Sept 2018
#
# This code employs the library 'simpledbf' to convert dbf files to csv files.
#
# You will need to install simpledbf to use (eg. pip install simpledbf).

# %%
import simpledbf # Import the simpledbf library
from simpledbf import Dbf5 # From the library import Dbf5

# %%
dbfTSI = Dbf5('S_USA_Activity_SilvTSI.dbf', codec='utf-8') # Import the dbf and assign the code

# %%
dbfTSI.to_csv('USA_STSI_TRT.csv') # Covert to csv

# %%
SilvTSI = pd.read_csv('USA_STSI_TRT.csv') # Assign new csv to new dataframe
# Out:
# /Users/kathrynmurenbeeld/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,1,3,5,6,7,10,12,15,17,21,22,23,25,28,29,31,37,39,44,45,49,50,51,53,56,58,61,65,66,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
SilvTSI.iloc[:,10:25].head(10) # Sanity check of data
# Out:
#   SUBUNIT              SALE_NAME ACTIVITY_C             ACTIVITY_N  \
# 0     000                    NaN       4511  Tree Release and Weed
# 1     000                    NaN       4521     Precommercial Thin
# 2     000                    NaN       4521     Precommercial Thin
# 3     000                    NaN       4521     Precommercial Thin
# 4     000              PORI JACK       4511  Tree Release and Weed
# 5     000             POWELL SBA       4521     Precommercial Thin
# 6     000  LEGACY MIGRATION SALE       4521     Precommercial Thin
# 7     002        JUNCTION SHADOW       4511  Tree Release and Weed
# 8     000                    NaN       4521     Precommercial Thin
# 9     000            BISCUITROOT       4521     Precommercial Thin
#
#            ACTIVITY_1 NBR_UNITS_    UOM NBR_UNITS1  DATE_PLANN  DATE_ACCOM  \
# 0  AC7803001033410334          6  ACRES          6  1996-03-01  1996-09-01
# 1  AC1031201043410434         44  ACRES         44  1978-06-01  1978-06-01
# ...

# %%
dbfTH = Dbf5('S_USA_Activity_TimberHarvest.dbf',codec='utf-8')
dbfTH.to_csv('USA_TH_TRT.csv')
TH=pd.read_csv('USA_TH_TRT.csv')
TH.iloc[:,10:25].head(10)
# Out:
#   SUBUNIT    SUBUNIT_CN          SUBUNIT_NA  SUBUNIT_SI           SALE_NAME  \
# 0     000   20565010467    2311 BIG JUNIPER        81.0    2311 BIG JUNIPER
# 1     000  746886010602           LUNCH 074        93.0           LUNCH SBA
# 2     000   38418010304                 NaN        14.0                 NaN
# 3     000    2211010444        UPWFWR 5 TSI        30.0        TRIPLE CREEK
# 4     000    2211010444        UPWFWR 5 TSI        34.0        SHEEP WEISER
# 5     000     463010456                 NaN        41.0  SONNY MEADOW SOUTH
# 6     000     463010456                 NaN         0.0                 NaN
# 7     000     463010456                 NaN         0.0                 NaN
# 8     0V0  772280010602                 NaN         0.5      IVY CK SALV #2
# 9     000   37180010344  TSMRS LEGACY STAND        40.0                 NaN
#
#   UNIT_ID      ACTIVITY_C      ACTIVITY_1  ACTIVITY_2  \
# 0     NaN  AU412693010467  AU412693010467        4113
# ...

# %%
TH.iloc[:,20:30].head(10)
# Out:
#              TREATMENT_  NBR_UNITS_    UOM  NBR_UNITS1  DATE_PLANN  \
# 0  Stand Clearcutting(E        81.0  ACRES        81.0  1970-01-01
# 1   Commercial Thinning        93.0  ACRES        93.0  2011-04-15
# 2  Stand Clearcutting(E        14.0  ACRES        14.0  1986-03-01
# 3  Overstory removal cu        30.0  ACRES        30.0  1969-09-01
# 4  Stand Clearcutting(E        34.0  ACRES        34.0  1985-09-01
# 5   Commercial Thinning        41.0  ACRES        41.0  2006-11-16
# 6   Commercial Thinning        41.0  ACRES         0.0  2020-09-01
# 7   Commercial Thinning        32.0  ACRES         0.0  1980-06-15
# 8  Stand Clearcutting(E         0.5  ACRES         0.5  1966-01-01
# 9  Stand Clearcutting(E        40.0  ACRES        40.0  1966-10-01
#
#    DATE_ACCOM  DATE_COMPL  FY_PLANNED  FY_ACCOMPL  FY_COMPLET
# 0  1972-09-17  1972-09-17        1970      1972.0      1972.0
# 1  2011-09-15  2014-09-15        2011      2011.0      2014.0
# ...

# %%
dbfHF = Dbf5('S_USA_Activity_HazFuelTrt_PL.dbf',codec='utf-8')
dbfHF.to_csv('USA_HF_TRT.csv')
HF=pd.read_csv('USA_HF_TRT.csv')
HF.iloc[:,0:10].head(10)
# Out:
# /Users/kathrynmurenbeeld/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,5,7,8,9,12,13,14,15,16,17,21,22,27,28,29,30,31,33,34,35,41,42,43,52,53,60,61,62,63,64,65,66,67,68,69,70,71,72,75,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                   SUID    ORG ACTIVITY_C  \
# 0  011001A110100082000  11001       4193
# 1  011001A110100082000  11001       4455
# 2  011404A520100206000  11404       4220
# 3  011407A140200007000  11407       4521
# 4  011407A140200007000  11407       4530
# 5  011404A520100209000  11404       4183
# 6  011204A300400022002  11204       1153
# 7  011204A300400022002  11204       4152
# 8  011204A300400022002  11204       1130
# 9  011201A240100310000  11201       4511
#
#                                             ACTIVITY       LOCAL_QUAL  \
# ...

# %%
dbfIRR = Dbf5('S_USA_Activity_IRR_PL.dbf',codec='utf-8')
dbfIRR.to_csv('USA_IRR_TRT.csv')
IRR=pd.read_csv('USA_IRR_TRT.csv')
IRR.iloc[:,10:25].head(10)
# Out:
#    FY_PLANNED  FY_ACCOMPL  FY_COMPLET  ACTIVITY_U  REGION_COD  ADMIN_FORE  \
# 0        2013        2015      2015.0       11607           1          16
# 1        2013        2013      2013.0       11605           1          16
# 2        2017        2017      2017.0       10202           1           2
# 3        2013        2015      2015.0       11607           1          16
# 4        2014        2014      2014.0       11605           1          16
# 5        2013        2015      2015.0       11607           1          16
# 6        2014        2014      2014.0       10202           1           2
# 7        2016        2016      2016.0       10202           1           2
# 8        2012        2012      2012.0       11401           1          14
# 9        2015        2015      2015.0       11605           1          16
#
#    DISTRICT_C  HOME_ORG                            ADMIN_FO_1  \
# 0           7     11607                  Lolo National Forest
# ...

# %%
dbfSRF = Dbf5('S_USA_Activity_SilvReforestation.dbf',codec='utf-8')
dbfSRF.to_csv('USA_SRF_TRT.csv')
SRF=pd.read_csv('USA_SRF_TRT.csv')
SRF.iloc[:,10:25].head(10)
# Out:
# /Users/kathrynmurenbeeld/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   SUBUNIT              SALE_NAME  ACTIVITY_C  \
# 0     000                 DUNHAM        4493
# 1     000   DUMMY SALE FOR KV/BD        4382
# 2     000                    NaN        4493
# 3     000                    NaN        4382
# 4     000                    NaN        4493
# 5     000                    NaN        4382
# 6     000                    NaN        4493
# 7     000         HUCKLEBERRY_PC        4491
# 8     000  LEGACY MIGRATION SALE        4431
# 9     002                    NaN        4431
#
#                                           ACTIVITY_N            ACTIVITY_1  \
# 0  Site Preparation for Natural Regeneration - Other     AC170001033410334
# ...
